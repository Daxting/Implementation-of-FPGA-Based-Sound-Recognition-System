# %% [markdown]
# ### 馬路聲音與非車禍聲音結合測試

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import time as t
import wave
import math
from numpy.fft import fft
import sys
import re
import scipy.io as scio
import tensorflow_io as tfio
import librosa
from tensorflow.python.ops.numpy_ops import np_config

# %%
filepath1 = 'car_crash_dataset/soundsnap/bird/4081-barn_swallow_song_cut4_teesdale_140606.wav'
filepath2 = 'car_crash_dataset/ESC50/馬路聲音.wav'

import numpy as np
import wave

def read_wave(file):
    with wave.open(file, 'rb') as f:
        params = f.getparams()
        nchannels, sampwidth, framerate, nframes = params[:4]
        str_data = f.readframes(nframes)
        wave_data = np.frombuffer(str_data, dtype=np.int16)
        wave_data = wave_data.reshape(-1, nchannels)
    return wave_data, framerate

def write_wave(file, data, framerate):
    with wave.open(file, 'wb') as f:
        nchannels = data.shape[1] if len(data.shape) > 1 else 1
        sampwidth = 2  # 16-bit audio
        nframes = data.shape[0]
        comptype = "NONE"
        compname = "not compressed"
        f.setparams((nchannels, sampwidth, framerate, nframes, comptype, compname))
        f.writeframes(data.tobytes())

def mix_waves(wave1, wave2):
    # Ensure both waves have the same number of channels and frames
    min_length = min(len(wave1), len(wave2))
    wave1 = wave1[:min_length]
    wave2 = wave2[:min_length]
    
    # Mix waves by adding the samples
    mixed_wave = wave1 + wave2

    # Normalize to prevent clipping
    max_val = np.max(np.abs(mixed_wave))
    if max_val > 32767:
        mixed_wave = mixed_wave * (32767.0 / max_val)
    
    return mixed_wave.astype(np.int16)

# 讀取兩個聲音檔
wave1, framerate1 = read_wave(filepath1)
wave2, framerate2 = read_wave(filepath2)

# 確保兩個聲音檔有相同的採樣率
if framerate1 != framerate2:
    print(framerate1, framerate2)
    if framerate1 != framerate2:
        #raise ValueError("Sample rates do not match")
        target_rate = min(framerate1, framerate2)  # 選擇較低的採樣率
        if framerate1 != target_rate:
            wave1 = wave1.astype(np.float32)
            wave1 = librosa.resample(wave1, orig_sr=framerate1, target_sr=target_rate)
            wave1 = wave1.astype(np.int16)
        if framerate2 != target_rate:
            wave2 = wave2.astype(np.float32)
            wave2 = librosa.resample(wave2, orig_sr=framerate2, target_sr=target_rate)
            wave2 = wave2.astype(np.int16)
        framerate1 = framerate2 = target_rate  # 更新採樣率

# 混和音頻
mixed_wave = mix_waves(wave1, wave2)
print(mixed_wave.size)
abs_wave_data = [abs(i)for i in mixed_wave]
print(abs_wave_data[0])
wave_data = mixed_wave*1.0/(max(abs_wave_data))

# 寫入混合後的音頻文件
write_wave('new_wave.wav', mixed_wave, framerate1)

# %% [markdown]
# #### 聲音預處理端測試資料產生以及中間值輸出 (直接執行下方所有block即可)

# %%
def findsize(path1, delay, index):
    wlen=1024
    inc=128

    f = wave.open(f'{path1}', "rb")
    params = f.getparams()
    nchannels, sampwidth, framerate, nframes = params[:4]
    str_data = f.readframes(nframes)
    wave_data = np.frombuffer(str_data, dtype=np.short)
    wave_data = wave_data*1.0/(max(abs(wave_data)))
    time = np.arange(0, wlen) * (1.0 / framerate)
    fixed_signal = np.zeros(len(wave_data))
    # if delay != 0:
    #     zeros=np.zeros(((wlen//11*delay),)) #在訊號前加0增加訓練集
    #     fixed_signal=np.concatenate((zeros,wave_data)) #填補後的信號記爲fixed_signal
    # else:
    fixed_signal = wave_data
    #print(wave_data.dtype)
    signal_length=len(fixed_signal) #信號總長度
    if signal_length<=wlen: #若信號長度小於一個幀的長度，則幀數定義爲1
        nf=1
    else: #否則，計算幀的總長度
        nf=int(np.ceil((1.0*signal_length-wlen+inc)/inc))
    pad_length=int((nf-1)*inc+wlen) #所有幀加起來總的鋪平後的長度
    zeros=np.zeros((pad_length-signal_length,)) #不夠的長度使用0填補，類似於FFT中的擴充數組操作
    pad_signal=np.concatenate((fixed_signal,zeros)) #填補後的信號記爲pad_signal
    indices=np.tile(np.arange(0,wlen),(nf,1))+np.tile(np.arange(0,nf*inc,inc),(wlen,1)).T  #相當於對所有幀的時間點進行抽取，得到nf*nw長度的矩陣
    indices=np.array(indices,dtype=np.int32) #將indices轉化爲矩陣
    #print(indices.shape)
    size = indices.shape[0]
    return size

# %%
# 十進制轉回二進制
def float_to_fixed_binary(value, integer_bits = 5, decimal_bits = 10):

    #略小於數值則為0
    if value < 9.7656*(10**-4) and value > -9.7656*(10**-4):
        binary_representation = '0000000000000000'
        return binary_representation

    # 考慮正負號
    sign = 0 if value >= 0 else 1
    abs_value = abs(value)

    # 將浮點數轉換為固定點表示法
    fixed_integer = int(abs_value * (2 ** decimal_bits))
    # 限制整數部分的位數
    #fixed_integer = fixed_integer % (2 ** (integer_bits + decimal_bits))

    # 考慮正負號
    sign_bit = '0' if sign == 0 else '1'
    
    # 生成二進位表示法
    binary_representation = format(fixed_integer, f'0{integer_bits + decimal_bits}b')
    
    # 如果是負數，進行二補數表示法的轉換
    if sign == 1:
        binary_representation = ''.join('1' if bit == '0' else '0' for bit in binary_representation)

        # 進行二進位加法，將結果加 1
        carry = 1
        for i in range(len(binary_representation) - 1, -1, -1):
            bit_sum = int(binary_representation[i]) + carry
            binary_representation = binary_representation[:i] + str(bit_sum % 2) + binary_representation[i+1:]
            carry = bit_sum // 2

    # 加上正負號位元
    binary_representation = f'{sign_bit}{binary_representation}'

    return binary_representation

# %%
def verilog_testbench(soundsignal):
    for i in range(soundsignal.shape[0]):
        if soundsignal[i] < -31:
            print(i, soundsignal[i])
            raise ValueError("data too small!")
        elif soundsignal[i] > 31:
            raise ValueError("data too big!")
        else:
            binarytestbench = float_to_fixed_binary(soundsignal[i])
        print(f'        #30 sound_input = 16\'b{binarytestbench}; sound_input_Rready = 1\'b1;')
        print('        #30 sound_input_Rready = 1\'b0;')
    return

# %%
def add_white_noise(signal, noise_factor = 0.005):
    noise = np.random.normal(loc = 0, scale = signal.std(), size = len(signal))
    augmented_signal = signal + noise*noise_factor
    return augmented_signal

def audioProcessing(path1, delay, designated = 0, maxindex = 167, addenvnoise = 0):
    wlen=1024
    inc=128

    f = wave.open(f'{path1}', "rb")
    params = f.getparams()
    nchannels, sampwidth, framerate, nframes = params[:4]
    str_data = f.readframes(nframes)
    wave_data = np.frombuffer(str_data, dtype=np.short)
    wave_data = wave_data*1.0/(max(abs(wave_data)))
    if delay == 1: #add white noise

        wave_data = add_white_noise(wave_data, 0.5)

    elif delay == 3:
        wave_data = add_white_noise(wave_data, 0.3)
    elif delay == 2:
        wave_data = add_white_noise(wave_data, 0.4)
    time = np.arange(0, wlen) * (1.0 / framerate)
    fixed_signal = np.zeros(len(wave_data))
    fixed_signal = wave_data
    #print(wave_data.dtype)
    signal_length=len(fixed_signal) #信號總長度
    if signal_length<=wlen: #若信號長度小於一個幀的長度，則幀數定義爲1
        nf=1
    else: #否則，計算幀的總長度
        nf=int(np.ceil((1.0*signal_length-wlen+inc)/inc))
    pad_length=int((nf-1)*inc+wlen) #所有幀加起來總的鋪平後的長度
    zeros=np.zeros((pad_length-signal_length,)) #不夠的長度使用0填補，類似於FFT中的擴充數組操作
    pad_signal=np.concatenate((fixed_signal,zeros)) #填補後的信號記爲pad_signal
    indices=np.tile(np.arange(0,wlen),(nf,1))+np.tile(np.arange(0,nf*inc,inc),(wlen,1)).T  #相當於對所有幀的時間點進行抽取，得到nf*nw長度的矩陣
    #print(indices[:2])
    indices=np.array(indices,dtype=np.int32) #將indices轉化爲矩陣
    frames=pad_signal[indices] #得到幀信號
    totaltime = np.linspace(0, 1.0/framerate*nframes, signal_length)


    maxamplitude = maxindex #max amplitude 所在的窗
    plt_time = time + inc /framerate*maxamplitude

    np.set_printoptions(threshold=sys.maxsize)
    print(frames.shape[1])
    #print(type(fixed_signal))
    #print(fixed_signal)
    print('original: ', frames[designated])
    verilog_testbench(frames[designated])
    
    b = np.zeros((frames.shape[0], frames.shape[1]))
    for i in range(0, frames.shape[0]):
        windown=np.hamming(wlen)  #調用漢明窗
        a=frames[i:i+1]
        b[i]=a[0]*windown
    
    print('window: ', b[designated])

    #FFT

    Xtest = fft(b[0])
    X = np.zeros((b.shape[0], len(Xtest)),dtype=np.complex_)

    for i in range(0, b.shape[0]):
        X[i] = fft(b[i])
        N = len(X[0])
        n = np.arange(N)
        T = N/framerate
        freq = n/T 

    n_oneside = N//2


    # get the one side frequency
    f_oneside = freq[:n_oneside]

    # normalize the amplitude
    X_oneside = np.zeros((X.shape[0], f_oneside.shape[0]),dtype=np.complex_)
    for i in range (0, X.shape[0]):
        X_oneside[i] =X[i][:n_oneside]/n_oneside

    
    square_X = np.zeros((X_oneside.shape[0], X_oneside.shape[1]))
    square_X = np.square(np.abs(X_oneside))

    print('fft: ', square_X[designated])
    
    #頻率點數量
    fp = n_oneside
    #設計濾波器的最低頻率
    fl = freq[0]
    #設計濾波器的最高頻率
    fh = freq[fp]
    #print(f'maximum freq: {fh}')
    #最低頻率對應的mel頻率
    melfl = 2595.0 * np.log10(1 + fl/700.0)
    #最高頻率對應的mel頻率
    melfh = 2595.0 * np.log10(1 + fh/700.0)
    # melfl 到 melfh 之間的濾波器個數
    p = 64
    #間隔點頻率(包括最低頻點及最高頻點)
    MelF = np.linspace(melfl, melfh, p+2)
    #將mel頻率轉回實際頻率
    F = 700.0 * (10 ** (MelF/2595.0) - 1)
    bank = np.zeros((p, fp))


    for m in range(1, p+1):
        F_left = F[m - 1]
        F_mid = F[m]
        F_right = F[m + 1]
        for k in range(0, fp):
            
            if f_oneside[k] >= F_left and f_oneside[k] <= F_mid:
                bank[m - 1][k] = (f_oneside[k] - F_left)/(F_mid - F_left)
            elif f_oneside[k] > F_mid and f_oneside[k] <= F_right:
                bank[m - 1][k] = (F_right - f_oneside[k])/(F_right - F_mid)        


    mel_X = np.matmul(square_X, np.transpose(bank))

    print('mel: ', mel_X[designated])

    #min_positive_float = np.finfo(float).eps
    min_positive_float = 10**-7
    for i in range(mel_X.shape[0]):
        for j in range(mel_X.shape[1]):
            if mel_X[i][j] < 10**-7:
                mel_X[i][j] = min_positive_float

    
    log_X = np.log10(mel_X)
    for i in range(log_X.shape[0]):
        for j in range(log_X.shape[1]):
            if log_X[i][j] < -7:
                print("minimum overflow")
            if  log_X[i][j] > 7:
                print("maximum overflow")
    
    print('log10: ', log_X[designated])
    
    return log_X

# %%
signal1 = np.zeros((1, 64, 64)) #car_horn 8音檔
index = 1
maxindex = 0
#原始音檔 & 修改音檔增加訓練資料
path1 = 'car_crash_dataset/soundsnap/0s/11874-CAR_WINDOW_SMASH_1.wav'
for i in range(1): #i 表示平移量
    signal_size = findsize(path1, i, index)
    temp_signal = np.zeros((signal_size, 64))
    temp_signal = audioProcessing(path1, i, index, maxindex)
    num_matrices = temp_signal.shape[0] // 64
    # 使用 numpy.reshape 將原始陣列轉換為三維矩陣
    signal1 = np.append(signal1, temp_signal[:num_matrices * 64, :].reshape((num_matrices, 64, 64)), axis = 0)
    index += 1
# Out:
# 1024
# original:  [-6.10370190e-05 -7.29087191e-02 -1.32847072e-01 -7.01925718e-04
#  -6.14947966e-02  9.45310831e-01  1.22074038e-04 -2.57271035e-02
#   2.73415326e-01  2.44148076e-04  1.64403211e-01 -4.68764306e-01
#  -3.05185095e-05 -1.95135350e-01  2.57789850e-01 -2.74666585e-04
#   2.09387494e-01 -8.12524796e-01  8.23999756e-04  8.47193823e-02
#   1.71880245e-01  6.10370190e-04  2.61787774e-01  6.71895505e-01
#   6.71407208e-04 -3.77208777e-02 -2.34687338e-02 -5.79851680e-04
#  -4.01013215e-02  9.84374523e-01 -6.10370190e-05 -5.92669454e-02
#  -9.60997345e-01 -3.35703604e-04 -1.60344249e-01  6.24713889e-02
#  -5.49333171e-04 -1.14017151e-01 -8.90682699e-01 -7.93481246e-04
#  -1.98919645e-01  4.68459120e-02 -5.79851680e-04 -9.07925657e-02
#   1.32786035e-01 -1.52592547e-04 -7.38547929e-02 -9.37559130e-01
#  -2.74666585e-04 -5.90838343e-02  6.56239509e-01 -4.27259133e-04
#  -8.36207160e-02  1.24973296e-01 -2.44148076e-04 -1.16275521e-02
#   5.70299387e-01  3.05185095e-05 -7.96838282e-02  2.81228065e-01
#  -3.05185095e-05  1.25949889e-01 -1.56254769e-01  1.83111057e-04
#   3.26853236e-02  9.53154088e-01  5.49333171e-04  1.59855953e-01
#   7.18771935e-01  4.27259133e-04  8.77407147e-02 -9.45341350e-01
#   5.49333171e-04  2.38929411e-01  6.40644551e-01  1.31229591e-03
#   6.15436262e-01 -5.07827998e-01  2.96029542e-03  5.58030946e-01
#   2.18756676e-01  1.64799951e-03  4.10992767e-01 -9.14090396e-01
#   8.23999756e-04 -1.75786615e-02  8.90621662e-01  3.05185095e-05
#   1.12949004e-01  6.56270028e-01  1.22074038e-04 -1.40476699e-01
#   3.90606403e-01 -7.32444227e-04 -8.54823450e-02 -9.06308176e-01
#  -2.74666585e-04  2.40485855e-02 -5.07827998e-01  1.00711081e-03
#   2.67128513e-01  4.84389782e-01  1.83111057e-04 -1.17435224e-01
#   7.78221992e-03 -5.49333171e-04  4.16272469e-02 -3.90636921e-02
#   1.12918485e-03  3.24350719e-01  9.92217780e-01  1.00711081e-03
#   3.50535600e-01 -9.84405042e-01  1.52592547e-03  3.66252632e-01
#  -7.26584674e-01  1.49540696e-03  4.24787133e-01 -3.82824183e-01
#   1.37333293e-03  1.43833735e-01 -3.59385968e-01 -3.35703604e-04
#  -2.43842891e-01 -4.29731132e-01 -9.46073794e-04 -9.93682669e-02
#  -7.89117100e-01 -1.83111057e-04 -6.08539079e-02  8.90621662e-01
#  -1.52592547e-04  8.17285684e-02 -1.95318461e-01  3.35703604e-04
#  -9.21658986e-03 -7.03451643e-02  0.00000000e+00  1.74993133e-01
#   8.12524796e-01  1.00711081e-03  1.69072542e-01 -6.17206336e-01
#   6.71407208e-04  1.37363811e-01 -4.06262398e-01 -3.96740623e-04
#  -2.43415632e-01 -2.18787194e-01 -1.37333293e-03 -4.20911283e-01
#  -5.07858516e-01 -1.61748100e-03 -4.60921049e-01  8.98434400e-01
#  -1.95318461e-03 -2.31330302e-01  5.39048433e-01  3.05185095e-05
#  -2.35602893e-02  3.59355449e-01 -6.10370190e-04 -5.49455245e-01
#   5.23422956e-01 -3.54014710e-03 -8.43745231e-01 -1.48472549e-01
#  -2.47199927e-03 -3.95001068e-01  4.14044618e-01 -1.09866634e-03
#  -3.20413831e-01 -7.10989715e-01 -1.64799951e-03 -5.24246956e-01
#   5.07797479e-01 -1.86162908e-03 -1.64616840e-01 -6.87551500e-01
#   9.15555284e-05 -1.89489425e-01  6.40614032e-01 -1.15970336e-03
#  -1.59001434e-01 -9.45371868e-01 -1.15970336e-03 -5.08133183e-01
#   7.78221992e-03 -1.55644398e-03 -1.99468978e-01 -9.84435560e-01
#  -9.76592303e-04 -4.83077486e-01 -5.15671255e-01 -2.31940672e-03
#  -3.64543596e-01  3.74980926e-01 -1.40385144e-03 -6.68233283e-01
#  -4.06292917e-01 -2.59407331e-03 -4.66658528e-01  4.84359264e-01
#  -7.32444227e-04  1.95623646e-02  4.06262398e-01 -1.25125889e-03
#  -6.10980560e-01  7.02841273e-02 -1.73955504e-03 -4.23749504e-01
#  -3.20352794e-01 -2.89925840e-03 -8.21771905e-01  5.23422956e-01
#  -1.92266610e-03 -3.00241096e-01 -2.10974456e-01 -1.95318461e-03
#  -5.93371380e-01  9.06247139e-01 -1.89214759e-03 -5.66820276e-01
#   2.89040803e-01 -2.77718436e-03 -5.26749474e-01  8.74996185e-01
#  -3.05185095e-04  4.27838984e-01 -6.95333720e-01  2.65511032e-03
#   7.28232673e-01 -8.51588488e-01  3.08236946e-03  6.84194464e-01
#  -9.14090396e-01  1.43436995e-03  3.43028047e-01  4.21887875e-01
#   2.50251778e-03  7.74498733e-01 -2.89071322e-01  1.98370312e-03
#   2.70729698e-01 -5.54704428e-01  2.10577715e-03  9.23123875e-01
#  -7.50022889e-01  3.99792474e-03 -7.93145543e-01 -9.14090396e-01
#   5.82903531e-03 -2.91543321e-01  5.15640736e-01  6.43940550e-03
#  -7.19779046e-01 -2.34382153e-02  3.57066561e-03  7.33329264e-01
#  -1.56254769e-01  2.22785119e-03  3.62407300e-01 -7.03146458e-01
#   1.06814783e-03  4.62660604e-01  5.46891690e-02  2.50251778e-03
#   6.22730186e-01  1.79692984e-01  2.13629566e-03  4.86831263e-01
#   9.29715873e-01  1.55644398e-03  3.00393689e-01  5.46891690e-01
#   1.19022187e-03  5.14908292e-01  7.34397412e-01  1.55644398e-03
#  -2.52876370e-01  6.24713889e-02 -2.62459181e-03 -7.42332224e-01
#  -8.43806269e-01 -3.29599902e-03 -6.34388256e-01  7.81243324e-01
#  -4.57777642e-04  1.35929441e-01 -5.46891690e-02  1.22074038e-04
#  -1.74871059e-01 -9.37559130e-01 -1.70903653e-03 -6.26545000e-01
#   4.68459120e-02 -2.22785119e-03 -8.88393811e-02 -8.43806269e-01
#   1.09866634e-03  3.01095614e-01 -9.76592303e-01  2.10577715e-03
#   8.13501389e-01  3.12509537e-02  3.54014710e-03  9.53581347e-01
#   0.00000000e+00  3.72325816e-03  9.08597064e-01  8.98464919e-01
#   2.53303629e-03  4.43250832e-01  1.40629292e-01  6.10370190e-04
#  -2.90475173e-01  5.78112125e-01 -1.15970336e-03 -2.54036073e-01
#   3.98419141e-01 -2.07525864e-03 -3.99121067e-01 -3.43791009e-01
#   9.15555284e-05 -4.09253212e-02 -4.84420301e-01 -8.54518265e-04
#   8.31324198e-02  3.82824183e-01  1.67851802e-03  2.08838160e-01
#  -7.81273843e-02 -2.59407331e-03  6.20441298e-01  9.60936308e-01
#  -5.73747978e-03  6.95577868e-01  7.65617847e-01 -4.33362835e-03
#  -5.89953307e-01  2.34351634e-01 -4.27259133e-04 -3.58897671e-02
#  -4.69069491e-02  9.15555284e-05  9.46073794e-03  9.06277657e-01
#   2.44148076e-04  3.78368480e-01 -6.87520981e-01  9.76592303e-04
#  -4.79140599e-01 -7.26615192e-01 -5.24918363e-03  3.44157231e-01
#   1.32786035e-01 -5.95110935e-03  5.99627674e-01  3.82793664e-01
#  -4.08948027e-03 -5.25803400e-01  6.79677725e-01 -9.76592303e-04
#  -1.73100986e-01 -9.60997345e-01  6.10370190e-05  1.81524094e-01
#   3.12509537e-02  7.93481246e-04  4.57167272e-01  4.92202521e-01
#   2.19733268e-03  2.85897397e-01 -8.20337535e-01  8.54518265e-04
#   2.91024506e-01  8.28150273e-01  6.71407208e-04  2.02856532e-01
#  -3.59385968e-01  1.70903653e-03  6.95852535e-01 -1.56254769e-02
#   3.72325816e-03 -9.31394391e-01  7.65648366e-01  2.74666585e-03
#   1.16794336e-01  1.64067507e-01  2.13629566e-04  3.47636341e-01
#  -6.79708243e-01  1.12918485e-03  1.17465743e-01  3.43760491e-01
#   9.76592303e-04  5.57115390e-01  1.40629292e-01  2.41096225e-03
#   6.84591205e-01  7.50022889e-01  3.44859157e-03  6.70888394e-01
#  -2.73445845e-01  7.93481246e-04  9.07315287e-02 -7.65648366e-01
#   1.28177740e-03  4.00158696e-01  5.07827998e-01  1.15970336e-03
#   2.06335643e-01 -7.42210150e-01 -6.40888699e-04 -4.14838099e-01
#  -9.37833796e-02 -2.31940672e-03  9.97894223e-01  9.60936308e-01
#  -3.57066561e-03 -1.97393719e-01  3.28104495e-01  1.31229591e-03
#   5.11123997e-01 -4.76577044e-01  2.13629566e-03  9.69145787e-01
#  -4.06262398e-01  6.25629444e-03 -6.60817286e-01 -3.90636921e-01
#   1.43436995e-03 -3.20108646e-01 -4.69069491e-02 -1.98370312e-03
#  -5.31754509e-01 -4.45356609e-01 -3.35703604e-03 -9.41862239e-01
#   1.79662465e-01 -1.64799951e-03  1.31321146e-01 -3.90636921e-02
#  -9.15555284e-05 -6.47907956e-01 -7.34427931e-01 -3.93688772e-03
#   7.54570147e-01 -7.18802454e-01 -6.25629444e-03  1.86132389e-01
#  -8.98495437e-01 -6.07318339e-03  5.88183233e-01  1.01535081e-01
#  -7.44651631e-03  2.08044679e-01 -3.43791009e-01 -5.73747978e-03
#   4.06445509e-01  3.98419141e-01 -4.11999878e-03 -1.87597278e-01
#  -9.76622822e-01  6.10370190e-04  2.52204962e-01 -6.95333720e-01
#   2.07525864e-03  6.58101138e-01  7.42210150e-01 -7.01925718e-04
#   8.96237068e-01  1.00000000e+00 -3.47911008e-03 -3.92529069e-01
#  -4.68794824e-01 -2.31940672e-03 -9.80590228e-01  1.17160558e-01
#  -3.57066561e-03 -4.74868007e-01 -8.82869961e-01 -2.22785119e-03
#  -9.76866970e-01  7.78221992e-03 -2.47199927e-03  1.03579821e-01
#  -2.34382153e-01  1.00711081e-03 -2.65694143e-01  1.32786035e-01
#  -1.86162908e-03 -3.11380352e-01 -6.64113285e-01 -1.67851802e-03
#  -4.88296152e-02 -7.57866146e-01  2.74666585e-03 -6.94387646e-01
#   5.93768120e-01  5.92059084e-03  8.23847163e-01 -5.07827998e-01
#   8.23999756e-04  3.83617664e-02  9.21903134e-01 -1.52592547e-03
#  -5.88610492e-01 -2.42225410e-01 -2.31940672e-03 -5.08407849e-01
#   2.96853542e-01  5.79851680e-04  2.69905698e-01 -3.82824183e-01
#  -2.59407331e-03 -4.21094394e-01 -8.43806269e-01  3.54014710e-03
#  -6.32740257e-01  3.43760491e-01  4.57777642e-03 -9.80071413e-01
#  -3.51573229e-01  4.21155431e-03  8.53236488e-01 -3.20322275e-01
#   1.28177740e-03  6.65791803e-01 -9.76592303e-01  4.36414686e-03
#  -9.86022523e-01  7.57835627e-01  4.30310984e-03 -6.47999512e-01
#   9.45341350e-01  5.24918363e-03 -9.59013642e-01 -7.57835627e-01
#   3.50962859e-03  9.66032899e-01 -7.10959197e-01  3.26548051e-03
#   8.97335734e-01 -5.39078951e-01  4.18103580e-03 -8.83449812e-01
#   3.35947752e-01  6.28681295e-03  3.96496475e-01  5.39109470e-01
#   9.61333048e-03 -2.61543626e-01 -7.65648366e-01  4.36414686e-03
#  -9.63744011e-01 -3.90636921e-02  3.32651753e-03  7.97570727e-01
#  -5.31266213e-01  4.15051729e-03  9.42686239e-01  3.90636921e-02
#   4.24207282e-03 -6.57124546e-01  7.34397412e-01  4.33362835e-03
#  -8.94802698e-01 -1.00003052e+00  3.66222114e-03  7.99615467e-01
#   7.10959197e-01  2.31940672e-03  1.08554338e-01 -5.78142644e-01
#  -9.15555284e-05 -8.49116489e-01 -7.65678884e-01 -6.01214637e-03
#  -7.17734306e-01 -6.95364238e-01  1.52592547e-04  3.38816492e-01
#  -2.34382153e-01  2.25836970e-03 -9.80376598e-01 -9.37528611e-01
#   6.86666463e-03 -3.46446120e-01  7.03146458e-01  2.04474013e-03
#  -7.92260506e-02 -9.76622822e-01 -2.74666585e-04 -3.13333537e-01
#   2.18726157e-01 -3.02133244e-03  5.20187994e-01  3.98419141e-01
#  -7.35496078e-03  5.53270058e-01  3.82793664e-01 -3.66222114e-03
#  -9.02798547e-01  1.00000000e+00 -4.33362835e-03  8.62300485e-01
#   8.67183447e-01 -4.15051729e-03 -5.77990051e-01  1.71849727e-01
#  -4.27259133e-04 -7.83013398e-01 -5.23483993e-01 -5.70696127e-03
#   7.01925718e-01 -4.92233039e-01 -5.46281320e-03  4.86922819e-01
#   3.59355449e-01 -3.63170263e-03 -4.69527268e-01 -7.57866146e-01
#  -2.74666585e-03 -9.94323557e-01  3.51542711e-01 -3.93688772e-03
#   8.67244484e-01  7.78221992e-03 -6.86666463e-03  3.15866573e-01
#  -9.14120914e-01 -3.75377667e-03  6.38874477e-01 -3.90667440e-01
#  -7.99584948e-03 -8.64894559e-02  5.07766961e-01 -7.20236824e-03
#   1.41636402e-01  7.42179632e-01 -9.09451582e-03  2.43903928e-01
#   9.60936308e-01 -2.80770287e-03 -3.07107761e-01  5.46861171e-01
#   7.93481246e-04  3.76598407e-01  5.00015259e-01 -6.10370190e-04
#  -5.96545305e-01  1.09347819e-01 -1.09866634e-03  4.57258827e-01
#   7.10959197e-01  3.75377667e-03  8.33094272e-01 -4.29700613e-01
#  -8.54518265e-04 -9.07254250e-01 -1.40659810e-01 -1.55644398e-03
#   4.48774682e-01 -5.93768120e-01  4.24207282e-03 -7.18070009e-01
#   7.03146458e-02  4.18103580e-03  6.96523942e-01 -5.23453475e-01
#  -1.34281442e-03  7.61650441e-01  1.55949583e-02 -2.80770287e-03
#  -3.16049684e-01  1.40598773e-01 -2.89925840e-03 -3.68297372e-01
#   7.18741417e-01  1.34281442e-03 -2.53761406e-01 -8.98495437e-01
#  -6.28681295e-03 -9.19827876e-02 -1.01626637e-01 -6.89718314e-03
#   5.44022950e-01  6.17175817e-01 -5.67644276e-03  7.12820826e-01
#  -7.73491623e-01 -2.77718436e-03 -5.55528428e-01  1.32786035e-01
#  -1.92266610e-03 -4.13830988e-02 -2.03161718e-01  9.46073794e-04
#  -8.27997681e-01 -7.03146458e-02  5.55436872e-03 -3.57066561e-02
#  -3.20352794e-01 -2.80770287e-03  1.08798486e-01 -6.32831812e-01
#   5.95110935e-03  5.07553331e-01 -9.45310831e-01  9.27762688e-03
#  -3.44035157e-01 -3.04696799e-01  2.96029542e-03 -3.53312784e-01
#  -7.73491623e-01 -2.92977691e-03 -9.59807123e-02 -2.42225410e-01
#   1.43436995e-03  1.53569140e-01  4.53138829e-01  1.22074038e-03
#   3.76964629e-01 -8.59401227e-02 -2.10577715e-03 -2.06122013e-01
#   4.06231880e-01  1.00711081e-03 -7.16147343e-01 -2.10974456e-01
#  -5.00503555e-03 -6.03900266e-01 -2.42225410e-01  1.31229591e-03
#   7.38639485e-01  3.20322275e-01  4.30310984e-03 -7.75658437e-01
#  -8.20337535e-01  8.20947905e-03 -2.47993408e-01 -6.32831812e-01
#   0.00000000e+00 -7.36503189e-01  3.82793664e-01 -2.71614734e-03
#   3.97473067e-01 -5.31266213e-01 -1.43436995e-03  3.09854427e-01
#   2.81258583e-01 -1.22074038e-04 -4.92812891e-01  5.85924863e-01
#  -6.07318339e-03  4.89822077e-01 -4.06292917e-01 -4.66933195e-03
#   4.55671865e-01  3.04666280e-01  1.49540696e-03 -9.28739280e-01
#  -3.51603748e-01  1.05899228e-02  6.15863521e-01 -4.92263558e-01
#   5.26444288e-02  2.88857692e-01  7.74132511e-01  1.46183660e-01
#  -4.64735862e-01  6.25598926e-01  1.41026032e-01 -7.13644826e-01
#   5.39048433e-01 -1.03244118e-01  7.25852229e-01  8.56959746e-02
#   5.16067995e-02  7.33207190e-01  3.67381817e-01  6.77510910e-03
#  -9.64995270e-01 -6.40278329e-01  1.93365276e-01  4.50544755e-01
#   8.28943754e-01  2.42072817e-01 -7.44438002e-01  3.84044923e-01
#   3.70677816e-01 -8.81008332e-01 -1.93945128e-01  2.49366741e-01
#  -1.42979217e-01 -8.43470565e-01 -3.22275460e-02 -7.18710898e-01
#   1.32633442e-01 -2.88094729e-02  5.47410504e-01  7.10806604e-01
#  -5.30411695e-02 -5.79088717e-01 -8.44080935e-01 -8.92361217e-02
#  -1.67607654e-01  9.52665792e-01 -9.49125645e-02 -3.44553972e-01
#   7.62962737e-03 -7.57774590e-02  5.13626514e-02 -3.75469222e-01
#  -9.57976012e-02 -3.67809076e-01 -8.05078280e-01 -5.97857601e-02
#   2.93069246e-01 -3.82915738e-01 -3.20444349e-02  6.60145878e-01
#   1.79509873e-01 -3.74156926e-02  6.61488693e-01 -1.33182775e-01
#  -2.17688528e-01 -8.36878567e-01  9.91149632e-01 -2.23029267e-01
#   8.03277688e-01 -1.72704245e-01 -2.71065401e-01  6.39881588e-01
#   3.50230415e-01 -3.49314859e-01  1.95318461e-02  5.84582049e-01
#  -3.52702414e-01  9.22147282e-01 -6.80898465e-01 -1.80608539e-01
#   1.95074313e-01  4.14044618e-01  6.39667959e-02 -1.26133000e-01
#   3.89416181e-02 -1.18655965e-01  6.51112400e-01 -5.63097018e-01
#  -1.88665426e-01 -2.73445845e-02  2.17627491e-01 -3.33506272e-01
#  -2.50160222e-01  9.90844447e-01 -3.51878414e-01  3.06955168e-01
#  -8.68556780e-01 -2.88308359e-01 -1.05105747e-01 -6.72505875e-01
#  -5.18204291e-02 -7.16818751e-01  7.65434736e-01 -1.09256264e-02
#   9.32615131e-01 -1.55034028e-02  5.38651692e-02  6.27521592e-01
#  -9.91912595e-01  1.03946043e-01  3.33017975e-01 -6.00909452e-01
#   2.51777703e-01  2.21137120e-01 -7.10043641e-01  1.86376537e-01
#  -1.90466018e-01 -5.61815241e-01  1.86132389e-01  1.46855068e-01
#   5.08285775e-01  2.52998444e-02 -4.39161351e-02  1.57170324e-02
#   9.84527116e-02  6.28681295e-03 -9.83947264e-01  1.29337443e-01
#   6.08111820e-01  5.24063845e-01  1.72093875e-01 -7.05374310e-01
#  -8.58821375e-01  1.65044099e-01  1.78350169e-01 -1.70873135e-01
#   2.52510147e-01  9.52879421e-01 -4.99435408e-01  2.03863643e-01
#   9.08871731e-01  2.98104801e-01  3.04818873e-01  1.51921140e-01
#  -3.34910123e-01  2.49855037e-01 -5.83147679e-01  3.60087893e-01
#   1.52165288e-01  1.82103946e-01 -4.75844600e-01  1.84148686e-01
#   5.78783532e-01  9.30234687e-01  1.10232856e-01  1.71697134e-01
#  -5.46464431e-01  4.19019135e-02  2.35877560e-01  3.20139164e-01
#   1.93182165e-02  4.87624744e-01  1.33426923e-01  1.82622761e-01
#  -2.46955779e-01 -3.04239021e-01  1.00100711e-01 -4.65956603e-01
#  -4.84145634e-01 -1.48625141e-02  1.54423658e-02  2.80831324e-01
#  -2.05481124e-01  3.37717826e-01 -2.74239326e-01 -8.23389386e-02
#   1.20212409e-01 -5.39078951e-01  1.54423658e-02 -6.32343516e-02
#  -8.36054567e-01 -4.70900601e-02 -5.04684591e-01  2.73476363e-01
#   7.65099033e-02  6.46565142e-01 -8.56959746e-02  1.12704855e-01
#   4.15021210e-01  3.13272500e-01  1.94494461e-01  8.78414258e-01
#  -1.40018921e-01  1.25614185e-01  1.59489731e-01  5.94195379e-01
#   1.48686178e-01  6.80379650e-01  8.52015748e-01 -5.18814661e-02
#  -3.20108646e-01  8.19696646e-01 -1.27933592e-01  3.51115452e-01
#   8.04651021e-01  1.30436110e-01  8.12829981e-01  9.69481491e-01
#   1.42307810e-01 -6.37226478e-01 -3.97991882e-01  1.31138035e-01
#   6.32923368e-01 -8.35566271e-01 -1.28482925e-02  1.83477279e-01
#   3.07931761e-02 -8.22779015e-02 -8.40418714e-01  3.98358104e-01
#  -1.89214759e-02 -8.78566851e-01  2.32856227e-02 -3.48826563e-02
#  -5.23606067e-01  6.87490463e-01  3.28073977e-02 -2.91756951e-02
#  -1.79570910e-01  7.12912381e-02  8.62727744e-01  6.41285440e-01
#   3.11105686e-01  8.19269387e-01 -6.22577593e-03  3.90148625e-01
#   2.82662435e-01 -8.65810114e-01  3.64635151e-01 -8.85464034e-01
#  -8.73775445e-01  2.70882290e-01  7.99493393e-01 -5.85161901e-01
#   7.87682730e-02 -2.51777703e-01  1.55339213e-02  1.49845882e-02
#  -9.26084170e-01 -9.68443861e-01  1.05746635e-01 -5.46525468e-01
#   1.40842921e-01  2.96639912e-02  5.36637471e-01  6.48792993e-01
#   1.69286172e-01  1.13284707e-01  9.38230537e-01  1.49021882e-01]
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111110110110; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111101111000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111000010; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001111000111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111100110; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000100010111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000010101000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111000100000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111100111001; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000100000111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000011010110; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110011000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000001010110; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000010110000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000100001100; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001010110000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111011010; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111101000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111010111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001111101111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111000100; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110000101000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111101011100; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000111111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111110001100; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110001110000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111100110101; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000101111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111110100100; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000010000111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111110110101; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110001000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111000100; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001010011111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111110101011; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000001111111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111110101; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001001000111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111110101111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000100011111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000010000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111101100000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000100001; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001111010000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000010100011; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001011100000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000001011001; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110000111000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000011110100; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001010010000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000001; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001001110110; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110111111000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000011; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001000111011; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000011100000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000001; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000110100100; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110001011000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111101110; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001110001111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000001110011; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001010100000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111101110001; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000110001111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111110101001; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110001100000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000011000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110111111000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000001; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000100010001; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000111110000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111110001000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000101010; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111011000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000001; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000101001100; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001111111000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000001; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000101100110; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110000010000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000001; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000101110111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110100011000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000001; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000110110010; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111001111000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000001; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000010010011; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111010010000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111100000111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111001001000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111110011011; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110011011000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111000010; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001110001111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000001010011; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111100111000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111110111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111110111000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000010110011; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001101000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000001; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000010101101; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110110001000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000010001100; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111001100000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111100000111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111100100000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111111111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111001010001; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110111111000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111111111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111000101001; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001110010111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111111110; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111100010100; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001000100111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111101000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000101101111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110111001110; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001000010111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111111101; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110010100001; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111101101000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111111110; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111001101100; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000110100111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111111111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111010111000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110100101000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111111111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110111101000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001000000111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111111111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111101011000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110101000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111100111110; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001010001111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111111111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111101011110; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110000111000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111111111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110111111000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111111111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111100110100; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110000010000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111111111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111000010010; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110111110000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111111110; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111010001011; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000101111111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111111111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110101010100; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111001100000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111111110; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111000100011; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000111101111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000010100; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000110100000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111111111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110110001111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000001000111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111111111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111001001111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111010111000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111111110; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110010110111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001000010111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111111111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111011001101; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111100101000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111111110; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110110100001; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001110011111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111111111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110110111100; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000100100111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111111110; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110111100101; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001101111111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000110110110; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110100111000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000010; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001011101001; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110010011000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000011; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001010111100; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110001011000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000001; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000101011111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000110110000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000010; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001100011001; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111011011000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000010; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000100010101; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110111001000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000010; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001110110001; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110100000000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000100; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110011010100; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110001011000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000101; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111011010110; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001000010000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000110; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110100011111; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111111101000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000011; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001011101110; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111111101100000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000010; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000101110011; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b1111110100110000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000001; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000111011001; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000111000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000010; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001001111101; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000010111000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000010; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000111110010; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000001110111000; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000000000001; sound_input_Rready = 1'b1;
#         #30 sound_input_Rready = 1'b0;
#         #30 sound_input = 16'b0000000100110011; sound_input_Rready = 1'b1;
# ...
#  -8.04119310e-01 -3.29488645e-03  5.59544150e-01 -3.41400729e-01
#  -6.97191103e-03 -7.52440161e-02  4.40743972e-01 -6.23737638e-03
#   1.22376417e-01  6.39763730e-01 -7.82112816e-03  2.09256682e-01
#   8.22464826e-01 -2.39732834e-03 -2.61584643e-01  4.64659736e-01
#   6.72546818e-04  3.18407746e-01  4.21695594e-01 -5.13465339e-04
#  -5.00558220e-01  9.15178816e-02 -9.17144188e-04  3.80716016e-01
#   5.90394414e-01  3.10896445e-03  6.88148971e-01 -3.53986331e-01
#  -7.02045505e-04 -7.43339980e-01 -1.14930218e-01 -1.26821988e-03
#   3.64650979e-01 -4.81110665e-01  3.42749143e-03 -5.78530493e-01
#   5.64881701e-02  3.34918289e-03  5.56320792e-01 -4.16862253e-01
#  -1.06621964e-03  6.02966964e-01  1.23089240e-02 -2.20940823e-03
#  -2.47947654e-01  1.09965600e-01 -2.26060013e-03 -2.86277859e-01
#   5.56935517e-01  1.03724681e-03 -1.95396283e-01 -6.89639193e-01
#  -4.80997292e-03 -7.01480119e-02 -7.72509296e-02 -5.22571729e-03
#   4.10827940e-01  4.64526862e-01 -4.25821844e-03  5.32932652e-01
#  -5.76339457e-01 -2.06228520e-03 -4.11113787e-01  9.79287775e-02
#  -1.41303979e-03 -3.03079465e-02 -1.48268442e-01  6.88011257e-04
#  -6.00003312e-01 -5.07708699e-02  3.99611579e-03 -2.55963074e-02
#  -2.28808231e-01 -1.99801823e-03  7.71376639e-02 -4.47010156e-01
#   4.18796052e-03  3.55837707e-01 -6.60238130e-01  6.45518323e-03
#  -2.38457065e-01 -2.10378289e-01  2.03602768e-03 -2.42054679e-01
#  -5.27843439e-01 -1.99144951e-03 -6.49821044e-02 -1.63340677e-01
#   9.63364056e-04  1.02725333e-01  3.01883190e-01  8.09943426e-04
#   2.49083719e-01 -5.65514424e-02 -1.37991612e-03 -1.34507582e-01
#   2.63978176e-01  6.51677014e-04 -4.61432426e-01 -1.35355406e-01
#  -3.19729200e-03 -3.84113100e-01 -1.53398705e-01  8.27429809e-04
#   4.63680217e-01  2.00193089e-01  2.67737661e-03 -4.80454000e-01
#  -5.05844776e-01  5.03932975e-03 -1.51537066e-01 -3.84926341e-01
#   0.00000000e+00 -4.43866228e-01  2.29625277e-01 -1.62171545e-03
#   2.36202381e-01 -3.14219274e-01 -8.44334722e-04  1.81523468e-01
#   1.63980112e-01 -7.08284448e-05 -2.84547060e-01  3.36658998e-01
#  -3.47239821e-03  2.78679389e-01 -2.30010472e-01 -2.63022823e-03
#   2.55393390e-01  1.69898274e-01  8.29696899e-04 -5.12669741e-01
#  -1.93094295e-01  5.78587512e-03  3.34741267e-01 -2.66170017e-01
#   2.83164404e-02  1.54554998e-01  4.12017196e-01  7.73905249e-02
#  -2.44721450e-01  3.27662439e-01  7.34653676e-02 -3.69748175e-01
#   2.77766626e-01 -5.29095072e-02  3.69930779e-01  4.34334386e-02
#   2.60105721e-02  3.67482351e-01  1.83097236e-01  3.35754860e-03
#  -4.75511002e-01 -3.13704683e-01  9.41965298e-02  2.18215670e-01
#   3.99164546e-01  1.15888169e-01 -3.54303165e-01  1.81705948e-01
#   1.74345798e-01 -4.11917076e-01 -9.01385604e-02  1.15201801e-01
#  -6.56552775e-02 -3.84972401e-01 -1.46196423e-02 -3.24041365e-01
#   5.94323361e-02 -1.28296674e-02  2.42264777e-01  3.12616841e-01
#  -2.31816548e-02 -2.51497397e-01 -3.64263878e-01 -3.82651012e-02
#  -7.14122450e-02  4.03294710e-01 -3.99204284e-02 -1.43980823e-01
#   3.16747328e-03 -3.12534674e-02  2.10445863e-02 -1.52822854e-01
#  -3.87325224e-02 -1.47719186e-01 -3.21167795e-01 -2.36895663e-02
#   1.15340306e-01 -1.49675786e-01 -1.24401143e-02  2.54519465e-01
#   6.87328935e-02 -1.42269274e-02  2.49773631e-01 -4.99372730e-02
#  -8.10495545e-02 -3.09386639e-01  3.63821210e-01 -8.12841660e-02
#   2.90663635e-01 -6.20432401e-02 -9.66757466e-02  2.26558599e-01
#   1.23099914e-01 -1.21879131e-01  6.76471320e-03  2.00969782e-01
#  -1.20353372e-01  3.12320145e-01 -2.28884953e-01 -6.02550746e-02
#   6.45893856e-02  1.36050195e-01  2.08584865e-02 -4.08148576e-02
#   1.25040326e-02 -3.78057087e-02  2.05845143e-01 -1.76632194e-01
#  -5.87172964e-02 -8.44339798e-03  6.66679320e-02 -1.01356036e-01
#  -7.54208339e-02  2.96340559e-01 -1.04394076e-01  9.03318410e-02
#  -2.53531474e-01 -8.34725595e-02 -3.01821982e-02 -1.91532944e-01
#  -1.46371491e-02 -2.00797382e-01  2.12635208e-01 -3.00979427e-03
#   2.54766039e-01 -4.19952239e-03  1.44677132e-02  1.67118589e-01
#  -2.61914159e-01  2.72124919e-02  8.64347013e-02 -1.54623313e-01
#   6.42264769e-02  5.59209879e-02 -1.77991841e-01  4.63120198e-02
#  -4.69129821e-02 -1.37160101e-01  4.50402432e-02  3.52207039e-02
#   1.20818452e-01  5.95998759e-03 -1.02527384e-02  3.63630853e-03
#   2.25724406e-02  1.42832942e-03 -2.21514992e-01  2.88519782e-02
#   1.34413061e-01  1.14771942e-01  3.73419834e-02 -1.51641862e-01
#  -1.82918244e-01  3.48254107e-02  3.72820124e-02 -3.53848090e-02
#   5.17996703e-02  1.93632931e-01 -1.00531443e-01  4.06473353e-02
#   1.79495351e-01  5.83131766e-02  5.90575912e-02  2.91526131e-02
#  -6.36505915e-02  4.70291259e-02 -1.08705614e-01  6.64762973e-02
#   2.78194995e-02  3.29700280e-02 -8.53144245e-02  3.26945027e-02
#   1.01756654e-01  1.61946590e-01  1.90027035e-02  2.93079349e-02
#  -9.23623692e-02  7.01247867e-03  3.90861406e-02  5.25252080e-02
#   3.13822142e-03  7.84305165e-02  2.12481566e-02  2.87943491e-02
#  -3.85516297e-02 -4.70226135e-02  1.53177486e-02 -7.05939256e-02
#  -7.26207413e-02 -2.20718638e-03  2.27050514e-03  4.08805365e-02
#  -2.96146385e-02  4.81896382e-02 -3.87433318e-02 -1.15170989e-02
#   1.66479773e-02 -7.39168327e-02  2.09647073e-03 -8.49998142e-03
#  -1.11274639e-01 -6.20576030e-03 -6.58564501e-02  3.53361934e-02
#   9.78924847e-03  8.19193762e-02 -1.07519997e-02  1.40035669e-02
#   5.10678125e-02  3.81763867e-02  2.34742125e-02  1.05005269e-01
#  -1.65784559e-02  1.47319571e-02  1.85284355e-02  6.83817991e-02
#   1.69515403e-02  7.68493923e-02  9.53480261e-02 -5.75276839e-03
#  -3.51713820e-02  8.92484369e-02 -1.38043763e-02  3.75489207e-02
#   8.52908178e-02  1.37048074e-02  8.46622340e-02  1.00110658e-01
#   1.45699331e-02 -6.46918080e-02 -4.00678803e-02  1.30935962e-02
#   6.26804897e-02 -8.20837968e-02 -1.25216912e-03  1.77414096e-02
#   2.95459022e-03 -7.83453235e-03 -7.94262996e-02  3.73709507e-02
#  -1.76222757e-03 -8.12427098e-02  2.13824592e-03 -3.18125616e-03
#  -4.74322399e-02  6.18696369e-02  2.93351372e-03 -2.59243567e-03
#  -1.58584097e-02  6.25841781e-03  7.52967440e-02  5.56542765e-02
#   2.68517079e-02  7.03365290e-02 -5.31756369e-04  3.31581567e-02
#   2.39081975e-02 -7.28951168e-02  3.05640692e-02 -7.39062935e-02
#  -7.26357329e-02  2.24312939e-02  6.59623491e-02 -4.81116339e-02
#   6.45512259e-03 -2.05701160e-02  1.26547901e-03  1.21748021e-03
#  -7.50586008e-02 -7.83154991e-02  8.53402886e-03 -4.40254540e-02
#   1.13273025e-02  2.38238374e-03  4.30473897e-02  5.19935012e-02
#   1.35561124e-02  9.06670811e-03  7.50665833e-02  1.19217505e-02]
# fft:  [3.48046001e-04 4.23422433e-04 7.12507462e-04 1.20293858e-03
#  1.03141261e-03 1.81899136e-04 2.26742946e-04 2.13490148e-04
#  5.08695991e-04 1.72370928e-04 1.15731573e-04 8.46232042e-06
#  1.06144821e-04 2.52667544e-04 5.94142375e-04 2.45454503e-04
#  4.05740046e-04 9.53536932e-05 1.15719156e-04 5.04474353e-05
#  1.58336965e-04 7.26020568e-04 1.43339797e-03 8.65351011e-04
#  4.20477379e-04 4.83836221e-04 2.01980037e-05 1.17079042e-03
#  8.49922758e-04 4.82554701e-05 3.96547278e-04 9.44187793e-04
#  4.84747724e-04 4.12748707e-05 2.92307670e-04 2.45645559e-04
#  2.22948368e-04 3.51660546e-04 7.83392905e-05 2.17369272e-04
#  3.32601149e-04 2.25928860e-04 1.66563145e-04 1.39739856e-04
#  1.14503269e-04 2.82731091e-04 6.49270084e-04 3.73705612e-04
#  2.54449371e-04 9.23627584e-05 7.90241884e-05 4.47275974e-05
#  1.36884493e-04 1.09658208e-04 1.59292828e-04 2.83300170e-04
#  5.10628448e-04 7.29720865e-04 2.52847779e-04 4.69767452e-05
#  3.49670786e-05 7.49022175e-04 1.30812329e-03 5.00431705e-06
#  1.97357414e-04 9.40549746e-05 3.19348440e-04 3.67490409e-04
#  6.68636952e-05 2.73368361e-04 3.44033309e-04 7.28373958e-04
#  7.22587441e-04 3.92081793e-04 5.25324249e-05 5.04541040e-06
#  2.00005694e-04 8.11797689e-05 1.47013907e-04 2.40455833e-04
#  1.68913033e-04 2.82156224e-04 2.07008448e-04 8.28494830e-05
#  2.97678175e-05 2.18981851e-05 5.73328275e-04 9.97362255e-04
#  2.34610031e-04 1.03304813e-03 1.58678617e-03 2.29044538e-04
#  2.49728834e-04 2.04485353e-04 4.09398971e-04 3.15462507e-04
#  3.94224979e-05 1.13275784e-04 6.71559226e-05 1.03234629e-03
#  8.77079480e-04 3.64227398e-04 9.86712679e-04 5.45610676e-04
#  1.88429421e-04 5.50421874e-04 4.08978809e-04 4.08613515e-04
#  5.61264403e-04 4.68902613e-04 3.09704369e-04 6.33595590e-04
#  7.37495527e-04 6.66853806e-04 4.55839474e-04 6.49780265e-05
#  1.36918884e-04 2.58377633e-04 1.06027210e-04 2.68353063e-04
#  2.14373595e-05 4.49075574e-06 5.75462886e-05 7.06576649e-05
#  2.42053702e-04 1.73670058e-03 7.86040447e-04 2.99487202e-04
#  3.99235947e-04 5.27673220e-04 4.10569070e-04 6.37278227e-04
#  1.24414204e-03 1.21653286e-03 5.18182062e-04 1.76295618e-04
#  5.01726565e-04 2.93430054e-04 2.25911866e-04 3.11966846e-04
#  2.47029415e-05 5.67808155e-04 1.99940332e-03 6.21488387e-04
#  4.56450534e-05 2.29522112e-04 3.54365830e-04 4.99676793e-04
#  1.80577636e-04 2.79673373e-04 8.37627539e-05 5.71842002e-05
#  6.49318764e-05 3.60323360e-04 3.12685371e-04 1.72407523e-05
#  3.74380065e-04 1.10874076e-03 8.16747715e-04 6.48660643e-04
#  1.16420716e-05 2.81230160e-04 1.59849562e-04 1.14807365e-05
#  1.61590969e-04 2.49096963e-04 2.79315225e-04 3.57759833e-04
#  5.97072411e-04 3.23359632e-04 4.72647006e-05 3.84533859e-05
#  4.13680998e-04 1.05248352e-03 3.47696053e-04 7.23648910e-05
#  3.17988104e-05 4.68085021e-05 8.62585651e-05 1.72456862e-04
#  3.17177070e-05 2.69192452e-04 4.17069816e-04 8.91235820e-04
#  1.71030823e-04 1.21585809e-05 9.55645950e-05 9.10001307e-05
#  9.56111378e-05 1.14095116e-04 2.67314033e-04 1.43720835e-04
#  1.68602585e-04 1.23916550e-04 6.64124616e-05 3.23133080e-05
#  1.22118595e-04 1.18820728e-04 1.59974118e-05 6.40111527e-04
#  9.03932784e-04 3.52281395e-04 9.91280470e-05 7.63294321e-05
#  1.49508407e-04 3.87823945e-04 2.79490181e-04 4.78832551e-04
#  3.84807201e-04 3.57159419e-04 1.80646865e-04 2.17005001e-04
#  8.90761487e-05 3.10027113e-04 4.76500166e-04 3.29068066e-04
#  5.17346475e-04 8.73676964e-05 8.30196398e-04 4.87106489e-04
#  2.86563827e-05 3.99314798e-04 7.86517042e-04 3.49780721e-04
#  5.36516818e-05 1.45689510e-04 6.36543437e-05 1.84235682e-04
#  7.57702552e-04 3.80003171e-04 8.62229479e-05 1.69312293e-04
#  8.45565947e-04 1.60402064e-03 2.95022820e-04 3.87885113e-05
#  1.71111134e-04 1.30689949e-04 9.96216354e-06 1.02421414e-04
#  1.57654712e-04 3.01490152e-04 1.44813724e-03 4.73783225e-04
#  9.19989679e-06 1.05382515e-04 1.03974869e-04 3.66851608e-04
#  8.90621788e-05 2.39172496e-04 5.48476802e-04 1.06297769e-03
#  3.96724792e-04 2.65004520e-05 4.12250694e-05 9.25780081e-05
#  7.32921165e-05 1.96294405e-04 1.74421777e-04 3.01165270e-04
#  5.48003955e-04 6.93265690e-04 1.93166718e-04 1.81366108e-05
#  1.97312293e-04 3.07932223e-04 2.23492186e-04 1.35210464e-04
#  3.24083214e-04 5.02723102e-04 5.25786471e-04 1.39330240e-03
#  2.17315693e-03 1.08240137e-03 2.34627241e-04 3.35946643e-04
#  4.35996271e-04 4.67755864e-04 2.28169387e-04 9.92543153e-06
#  3.74901037e-04 1.12111601e-04 1.64410289e-04 5.86688280e-05
#  2.48550953e-04 1.83086176e-03 2.58026966e-03 1.12525263e-03
#  4.34551948e-04 5.02764030e-04 8.46504876e-05 1.63542772e-04
#  8.62028823e-05 1.04389984e-04 2.20549798e-04 1.53458374e-04
#  3.42508087e-04 2.47330300e-04 1.02489556e-03 6.16044947e-04
#  3.02115304e-04 2.29162523e-05 9.87365133e-05 9.47593152e-05
#  2.73758393e-04 2.96007371e-04 3.65402447e-05 1.96091439e-04
#  1.17079072e-04 8.24840365e-04 1.05825095e-03 3.89487161e-04
#  6.72271249e-05 7.97601213e-04 9.21059702e-04 5.38694264e-06
#  6.92888338e-04 8.93334403e-04 1.09415429e-03 9.45335570e-04
#  2.52283034e-04 3.63513322e-04 5.19748770e-04 2.98877181e-04
#  9.53177293e-05 6.13706831e-04 1.77123215e-04 6.27026938e-04
#  2.91228073e-04 1.62452610e-04 1.42513260e-04 1.43989469e-04
#  5.48236237e-05 1.02716405e-04 1.19169758e-04 4.64246176e-04
#  7.69146025e-05 2.31974262e-05 2.11477463e-04 6.69883598e-05
#  5.85186353e-06 2.72576559e-04 3.56021883e-04 6.63238904e-04
#  6.03153428e-04 6.70005347e-04 7.34621354e-04 1.35411776e-04
#  8.29806730e-04 3.45995702e-04 3.86291884e-05 3.09486815e-04
#  5.86694238e-05 3.41799928e-06 4.50716566e-05 2.95408773e-04
#  3.40367315e-06 1.71147919e-04 8.20769725e-05 2.26509770e-04
#  7.25750919e-04 5.29716580e-04 1.32484538e-04 1.92363591e-04
#  3.15876334e-06 2.87592915e-04 2.40039522e-04 2.53090926e-04
#  2.72498254e-04 3.93222367e-07 4.22805980e-05 7.80728358e-05
#  4.33776895e-05 9.37120362e-05 1.08536510e-04 2.74513675e-04
#  1.10501919e-04 1.41226498e-04 2.37222783e-04 1.38857007e-04
#  2.39683693e-04 5.50092537e-04 5.39751945e-05 4.98219242e-05
#  7.18608896e-04 6.55224506e-04 5.97010370e-05 3.02409044e-05
#  2.02849804e-04 2.57135578e-06 4.14830090e-05 3.10860638e-04
#  2.06705298e-04 8.46584797e-05 5.10748709e-05 2.29084485e-04
#  8.67812777e-04 9.05524325e-04 1.78496485e-04 3.97717248e-04
#  3.10956670e-04 2.31247770e-04 1.99942942e-04 9.70516608e-04
#  4.74414354e-04 3.66763039e-05 1.29226748e-04 1.19565263e-04
#  4.46491137e-04 2.22784383e-04 1.24189166e-03 1.02078933e-03
#  5.46587023e-05 1.92864596e-04 3.22846004e-04 2.70733172e-04
#  3.11598442e-04 7.60504057e-05 6.77618895e-04 4.08112274e-04
#  3.88028120e-04 9.78443329e-04 6.89969660e-04 1.59923639e-04
#  1.20436302e-04 2.83927952e-04 1.90035861e-04 1.81068556e-04
#  4.93832859e-04 2.59588370e-04 6.63336209e-04 1.35312272e-03
#  7.05776307e-04 1.00061424e-03 4.06053944e-04 3.43452151e-04
#  2.25390793e-04 6.18468175e-05 3.95390670e-05 1.36875164e-04
#  3.86789545e-04 1.20074054e-04 1.14747784e-04 1.67435622e-04
#  6.57706361e-04 1.52788430e-04 2.81540308e-04 5.00317284e-04
#  2.06715726e-04 3.12304107e-05 2.80818852e-04 3.48427806e-04
#  1.98956074e-04 3.26669598e-04 7.94440280e-05 2.92434871e-04
#  3.35874332e-05 2.02664570e-04 7.37003850e-05 1.73786705e-05
#  1.20315582e-04 3.85707781e-04 2.15590981e-04 1.21180348e-04
#  7.25506426e-04 1.44798797e-04 7.48657467e-04 2.01497293e-03
#  8.63100736e-04 2.57104206e-04 1.43321270e-04 7.70916623e-04
#  1.09582587e-03 4.47592851e-04 4.32734784e-04 5.93706024e-04
#  1.02343818e-04 1.17058082e-03 1.29704187e-03 2.90974165e-04
#  6.68792095e-05 1.65666037e-04 5.41314161e-05 1.24294877e-04
#  2.17041535e-04 1.96953254e-04 5.41387605e-04 7.33896613e-04
#  5.13316169e-04 5.83539749e-04 3.47511601e-04 2.04556064e-05
#  4.26148583e-04 5.86048039e-04 2.35594483e-04 2.91295973e-04
#  2.42801304e-04 2.70712190e-04 5.50430087e-04 8.51062987e-04
#  2.32503957e-04 1.38631036e-04 1.51952960e-05 5.42215209e-04
#  2.07237111e-04 5.94867198e-06 1.07338852e-04 1.75782148e-04
#  5.14669836e-05 7.57305929e-05 2.91223880e-04 4.03908220e-04]
# mel:  [3.47948223e-04 5.83508512e-04 1.00671704e-03 1.09898406e-03
#  4.67275803e-04 2.38883089e-04 3.37598357e-04 4.89643896e-04
#  1.78830636e-04 7.39781691e-05 2.27998513e-04 7.41025403e-04
#  5.09941369e-04 2.63460854e-04 1.77534257e-04 1.49454627e-03
#  1.85557141e-03 8.69540345e-04 1.62520434e-03 1.15099949e-03
#  1.06087593e-03 6.75226889e-04 6.24611957e-04 6.92071972e-04
#  7.35915322e-04 1.12685152e-03 3.57342238e-04 1.06011684e-03
#  1.42683595e-03 1.91738186e-03 1.09252177e-03 2.00498015e-03
#  7.89107852e-04 9.25670715e-04 3.13914604e-03 2.49721773e-03
#  2.94783531e-03 3.29318809e-03 3.25025839e-03 1.48419120e-03
#  4.45068375e-03 4.55180028e-03 4.22831690e-03 2.58282202e-03
#  3.22963608e-03 2.91234567e-03 2.45721321e-03 2.00650149e-03
#  3.53618900e-03 4.45065540e-03 4.98591700e-03 4.72027117e-03
#  4.54243354e-03 9.12515292e-03 7.98354214e-03 7.14338673e-03
#  7.01979868e-03 5.83447990e-03 4.16241228e-03 5.43513106e-03
#  9.06914409e-03 9.68366968e-03 9.00847559e-03 1.16035844e-02]
# log10:  [-3.45848538 -3.2339528  -2.99709258 -2.95900861 -3.33042671 -3.62181459
#  -3.47159968 -3.31011966 -3.74755808 -4.13089642 -3.64206798 -3.1301669
#  -3.29247975 -3.5792839  -3.75071783 -2.82549063 -2.73152233 -3.06071026
#  -2.78909203 -2.93892487 -2.9743354  -3.17055027 -3.20438971 -3.15984874
#  -3.13317215 -2.94813331 -3.44691565 -2.97464627 -2.84562596 -2.71729139
#  -2.9615699  -2.69788992 -3.10286364 -3.03354348 -2.50318848 -2.60254359
#  -2.53049678 -2.48238346 -2.48808211 -2.82851015 -2.35157326 -2.3418168
#  -2.37383247 -2.58790552 -2.49084641 -2.53575708 -2.60955716 -2.69756051
#  -2.45146453 -2.35157603 -2.30225496 -2.32603305 -2.34271142 -2.03975985
#  -2.09780438 -2.14609584 -2.15367534 -2.23399785 -2.38065491 -2.26478998
#  -2.0424337  -2.01396003 -2.04534869 -1.93540784]
